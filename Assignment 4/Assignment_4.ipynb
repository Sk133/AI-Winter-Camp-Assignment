# %%
# Mohammad Saad Bin Younus
# Roll No # KWOWAIC16614
# Assignment # 4
# Question 1
subjects = [84, 92, 95, 87, 98]
print("All Marks", subjects)
print("Total Marks", sum(subjects))
print("Average Marks", sum(subjects)/len(subjects))
# Out:
# All Marks [84, 92, 95, 87, 98]
# Total Marks 456
# Average Marks 91.2

# %%
# Question # 2
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print("List without any update and delete")
print(fruits)
fruits.append("pineappale")
print("List with appending new fruit")
print(fruits)
fruits.insert(2, "watermelon")
print("List with inserting on index 2, a new fruit")
print(fruits)
fruits.remove("banana")
print("List with removing banana")
print(fruits)
fruits.pop(6)
print("List with removing fruit on index 6")
print(fruits)
# Out:
# List without any update and delete
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']
# List with appending new fruit
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'pineappale']
# List with inserting on index 2, a new fruit
# ['apple', 'banana', 'watermelon', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'pineappale']
# List with removing banana
# ['apple', 'watermelon', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'pineappale']
# List with removing fruit on index 6
# ['apple', 'watermelon', 'cherry', 'orange', 'kiwi', 'melon', 'pineappale']

# %%
# Question 3
student = {
    "name" : "Mohammad Saad Bin Younus",
    "class" : "BSCS - 8A",
    "age" : "24",
    "marks" : 485
}
print("Name : ", student["name"])
print("Age : ", student["age"])
print("Class : ", student["class"])
print("Marks : ", student["marks"])
# Out:
# Name :  Mohammad Saad Bin Younus
# Age :  24
# Class :  BSCS - 8A
# Marks :  485

# %%
# Question 4
student_marks = {
    "Saad" : [75, 85, 88, 92, 98],
    "Sara" : [70, 82, 78, 80, 76],
    "Ali" : [80, 75, 90, 85, 88],
}
saad_percentage = (sum(student_marks["Saad"])/500)*100
ali_percentage = (sum(student_marks["Ali"])/500)*100
sara_percentage = (sum(student_marks["Sara"])/500)*100

print("Saad Percentage : ", saad_percentage)
print("Ali Percentage : ", ali_percentage)
print("Sara Percentage : ", sara_percentage)
# Out:
# Saad Percentage :  87.6
# Ali Percentage :  83.6
# Sara Percentage :  77.2

# %%
# Question 5
students = {
    "Saad" : 490,
    "Sara" : 470,
    "Ali" : 450,
    "Ahsan" : 460,
}

print("All Keys ", students.keys())
print("All Values ", students.values())
print("All Key-value pairs ", students.items())
students["Saad"] = 488
print("Updated Key-value pairs ", students.items())
students.pop("Ahsan")
print("Updated Key-value pairs ", students.items())
# Out:
# All Keys  dict_keys(['Saad', 'Sara', 'Ali', 'Ahsan'])
# All Values  dict_values([490, 470, 450, 460])
# All Key-value pairs  dict_items([('Saad', 490), ('Sara', 470), ('Ali', 450), ('Ahsan', 460)])
# Updated Key-value pairs  dict_items([('Saad', 488), ('Sara', 470), ('Ali', 450), ('Ahsan', 460)])
# Updated Key-value pairs  dict_items([('Saad', 488), ('Sara', 470), ('Ali', 450)])
